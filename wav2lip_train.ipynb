# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename)) 

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/train-wav2lip/wav2Lip_training/inference.py
# /kaggle/input/train-wav2lip/wav2Lip_training/preprocess.py
# /kaggle/input/train-wav2lip/wav2Lip_training/hparams.py
# /kaggle/input/train-wav2lip/wav2Lip_training/color_syncnet_train.py
# /kaggle/input/train-wav2lip/wav2Lip_training/README.md
# /kaggle/input/train-wav2lip/wav2Lip_training/Wav2Lip.yml
# /kaggle/input/train-wav2lip/wav2Lip_training/hq_wav2lip_train.py
# /kaggle/input/train-wav2lip/wav2Lip_training/wav2lip_train.py
# /kaggle/input/train-wav2lip/wav2Lip_training/requirements.txt
# /kaggle/input/train-wav2lip/wav2Lip_training/requirements_win.txt
# /kaggle/input/train-wav2lip/wav2Lip_training/audio.py
# /kaggle/input/train-wav2lip/wav2Lip_training/temp/README.md
# /kaggle/input/train-wav2lip/wav2Lip_training/sample_data/audio.wav
# /kaggle/input/train-wav2lip/wav2Lip_training/sample_data/foto.png
# /kaggle/input/train-wav2lip/wav2Lip_training/data_root/main/00001/00001.mp4
# ...

# %%
# !pip uninstall tensorflow tensorflow-gpu -y
# Out:
# Found existing installation: tensorflow 2.15.0
# Uninstalling tensorflow-2.15.0:
#   Successfully uninstalled tensorflow-2.15.0
# WARNING: Skipping tensorflow-gpu as it is not installed.

# %%
import shutil

source_path = '/kaggle/input/train-wav2lip/wav2Lip_training'

destination_path = '/kaggle/working/wav2lip'

shutil.copytree(source_path, destination_path)
# Out:
# '/kaggle/working/wav2lip'

# %%
# !cd /kaggle/working/wav2lip/ && pip install -r requirements.txt

# %%
# !cd /kaggle/working/wav2lip/ && python color_syncnet_train.py --data_root lrs2_preprocessed/ --checkpoint_dir checkpoints/
# Out:
# use_cuda: True
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ...

# %%
# !cd /kaggle/working/wav2lip/ && python hq_wav2lip_train.py --data_root lrs2_preprocessed/ --checkpoint_dir checkpoints/ --syncnet_checkpoint_path checkpoints/lipsync_expert.pth
# Out:
# use_cuda: True
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# total trainable params 36298035
# total DISC trainable params 14113793
# Load checkpoint from: checkpoints/lipsync_expert.pth
# Starting Epoch: 0
# ...

# %%
# !cd /kaggle/working/wav2lip/ && python inference.py --checkpoint_path checkpoints/wav2lip.pth --face sample_data/foto.png --audio sample_data/audio.wav
